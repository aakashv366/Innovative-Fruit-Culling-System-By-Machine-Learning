# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-3ce3544bf969> in <cell line: 3>()
#       1 import numpy as np
#       2 import tensorflow as tf
# ----> 3 from keras.preprocessing.image import ImageDataGenerator
#       4 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'ImageDataGenerator' from 'keras.preprocessing.image' (/usr/local/lib/python3.10/dist-packages/keras/api/preprocessing/image/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cnn = tf.keras.models.load_model('/content/drive/MyDrive/trained_model.h5')

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/fruits-360-original-size/Test/pear_1/r0_107.jpg'
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 275ms/step

# %%
print(predictions)
# Out:
# [[2.3102456e-09 3.9657331e-12 9.4162139e-08 1.9021513e-09 6.3819255e-11
#   1.2724327e-11 3.0376221e-10 1.0940665e-10 9.9999988e-01 1.6848774e-10
#   1.7063378e-11 8.4899145e-09 1.4087689e-11 3.7368092e-10 2.1532174e-09
#   3.3674064e-09 1.2277254e-09 5.2449103e-09 2.0553255e-11 8.3946135e-11
#   8.2433121e-10 4.4746047e-09 4.3765898e-09 1.1101585e-09]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 8

# %%
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Single image Prediction
print("It's a {}".format(test_set.class_names[result_index]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-8648f25ef206> in <cell line: 2>()
#       1 #Single image Prediction
# ----> 2 print("It's a {}".format(test_set.class_names[result_index]))
#
# NameError: name 'test_set' is not defined
